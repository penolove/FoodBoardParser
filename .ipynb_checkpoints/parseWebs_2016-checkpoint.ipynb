# %% [markdown]
# ## create Parser Class

# %%
import requests
from bs4 import BeautifulSoup
import googlemaps
import psycopg2
import time
import random

# %%
def parse_address(main_context):
    def check_addr_string(x):
        return ("地".decode('utf-8') in i) and ("址".decode('utf-8') in i)
    def clear_string(x):
        x= x.replace('地'.decode('utf-8'),'')
        x= x.replace('址'.decode('utf-8'),'')
        x= x.replace('：'.decode('utf-8'),'')
        x= x.replace("!@#$%^&*()[]{};:,./<>?\|`~-=_+", '')
        return x.strip()
    w=[clear_string(i) for i in  main_context.split('\n') if check_addr_string(i)  ]
    if len(w)==0:
        return [""]
    return list(set(w))

def parse_title(main_context):
    """used to parse title from main context"""
    def check_addr_string(x):
        return ("餐廳名稱".decode('utf-8') in i) or ("店名".decode('utf-8') in i) or ("店家名稱".decode('utf-8') in i)
    def clear_string(x):
        x= x.replace('餐廳名稱'.decode('utf-8'),'')
        x= x.replace('店名'.decode('utf-8'),'')
        x= x.replace('：'.decode('utf-8'),'')
        x= x.replace("!@#$%^&*()[]{};:,./<>?\|`~-=_+\'\"", '')
        return x.strip()
    w=[clear_string(i) for i in  main_context.split('\n') if check_addr_string(i)  ]
    if len(w)==0:
        return [""]
    return list(set(w))



##################################You Should fill your own key here ######################
##################################You Should fill your own key here ######################
##################################You Should fill your own key here ######################
##################################You Should fill your own key here ######################

def getLatLon(address):
    #1-5
    mykeys=["AIzaSyB3VU7yJZhnfn3yZtWB-Y7OWoh9D1iA8m8",
            "AIzaSyAlowHbmmfIsAAdGywwxiWi-jT6kjwAGQk",
            "AIzaSyBwGh6vpBLsNogMEyoeQk5hGGhSG_DXijs",
            "AIzaSyD_aEKp7K3Bv2j-_YLee_A8U1Mi6juiubI",
            "AIzaSyBGb_1EMRWPrXFuoyrrDCrr12Hx5PjBl7c",
            "AIzaSyAyEzqfl7QiqDTeJNbQMJX4BVgiknqzZsc",
            "AIzaSyC6PjDyAoyKaNiZytZ4X5_rgmK0JumLwbo",
            "AIzaSyB7DNp56xqS26PtOzktydnd9N7MagVyb1s",
            "AIzaSyD4-QT1CjGpoWbNAox4JPmWGypWuDlzTTo",
            "AIzaSyCGwTE-diiJZUhOkSdXw4GpodEI3Cbtivk"
           ]

    #mykey="AIzaSyCGwTE-diiJZUhOkSdXw4GpodEI3Cbtivk"

    if(address==""):
        return (181,91)
    
    gmaps = googlemaps.Client(key=mykeys[random.randint(0,9 )])
    geocode_result = gmaps.geocode(address)
    lat=geocode_result[0]['geometry']['location']['lat']
    lon=geocode_result[0]['geometry']['location']['lng']
    return (lat,lon)


##################################You Should fill your own key here ######################
##################################You Should fill your own key here ######################
##################################You Should fill your own key here ######################
##################################You Should fill your own key here ######################

# %%
class FoodArticleParser:
    """ this class is used to parse Food acrticles in ptt 
        we will get url, address, name(store),lat,lon infomations
        and get infomations that needed in write to postgres DB 
    """
    
    url=""
    address=""
    name=""
    lat=181
    lon=91
    hours=""
    soup=BeautifulSoup()
    def __init__(self,url):
        self.url=url
        res=requests.get(url)
        self.soup=BeautifulSoup(res.text)
        main_context=self.soup.select('#main-content')[0].text
        self.address=parse_address(main_context)[0]
        self.name=parse_title(main_context)[0].replace("%", '').replace("'","").replace("$", '')
        tu=getLatLon(self.address)
        self.lat=tu[0]
        self.lon=tu[1]

    def __str__(self):
         return "store_name : " + self.name.encode('utf-8') +"\n"+ \
         "address : " + self.address.encode('utf-8') +"\n" + \
         "lat,lon : " + str(self.lat)+" ,"+str(self.lon) +"\n"
        
    def get_store_tuple(self):
        if (self.name==""):
            return (self.address,str(self.lat)+","+str(self.lon),1)
        return (self.address,self.name,str(self.lat)+","+str(self.lon),1)
    
    def get_article_tuple(self):
        count=0
        a=[];
        for i in self.soup.select('.article-metaline'):
            count=0
            if(count==0):
                a.append(i.select('.article-meta-value')[0].text.split('(')[0].strip())
            else:
                a.append(i.select('.article-meta-value')[0].text.strip())
            count=count+1
        main_context=self.soup.select('#main-content')[0].text
        
        if(len(a)<3):
            a=['','','']

        return [str(self.lat)+","+str(self.lon),a[1],a[2],a[0],main_context,self.url]
    def get_push_tuple(self):
        pushs=self.soup.select('.push')
        pushset=[(self.url ,\
          i.select('.push-userid')[0].text, \
          i.select('.push-tag')[0].text, \
          i.select('.push-content')[0].text[2:]) for i in pushs ]
        
        return pushset
# Out:
# /home/stream/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /home/stream/anaconda2/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
class ParserSubmit():
    conn = None
    cur = None
    def submit(self,c):
        #for all articles need to check
        #at least get lat from googlemap API
        if(c.lat!=181):
            print c.address
            if(c.name==""):
                print("sent to StoreTable")
                self.cur.executemany("""INSERT INTO StoreTable(address,latlon,count) VALUES (%s,%s,%s) \
                ON CONFLICT (latlon) DO UPDATE SET count=StoreTable.count+1""", [c.get_store_tuple()])
            else:
                print("sent to StoreTable")
                self.cur.executemany("INSERT INTO StoreTable(address,storeName,latlon,count) VALUES (%s,%s,%s,%s) \
                ON CONFLICT (latlon) DO UPDATE SET count=StoreTable.count+1 , storeName='"+c.name+"'", [c.get_store_tuple()])
            print("sent to ArticleTable")
            self.cur.executemany("""INSERT INTO ArticleTable(latlon,title,Date,Author,Context,url) \
             VALUES (%s,%s,%s,%s,%s,%s) ON CONFLICT (url) DO NOTHING""", [c.get_article_tuple()])
            print("sent to Pushtable")
            self.cur.executemany("""INSERT INTO PushTable(url,userid,pushtag,pushcontext) VALUES (%s,%s,%s,%s) \
            ON CONFLICT DO NOTHING""", c.get_push_tuple())
            
            self.conn.commit()

            
    ##################################You Should fill your DBInfomation #####################
    ##################################You Should fill your DBInfomation #####################
    ##################################You Should fill your DBInfomation #####################
    ##################################You Should fill your DBInfomation #####################

    def connect(self):
        self.conn = psycopg2.connect("dbname='foodmining' user='penolove' host='localhost' password='password'")
        self.cur = self.conn.cursor()
    def reconnect(self):
        self.conn.close()
        self.conn = psycopg2.connect("dbname='foodmining' user='penolove' host='localhost' password='password'")
        self.cur = self.conn.cursor()
    def close(self):
        self.conn.close()

# %%
class MeauParser():
    urlist=[]
    def urlistUpdate(self,url):
        self.urlist=[]
        res=requests.get(url)
        soup=BeautifulSoup(res.text)
        for i in soup.select('.r-ent'):
            try:
                self.urlist.append('https://www.ptt.cc'+i.select('a')[0]['href'])
            except IndexError:
                pass
        #self.urlist=['https://www.ptt.cc'+i.select('a')[0]['href'] for i in soup.select('.r-ent')]
        return self.urlist

# %% [markdown]
# # =========== parse 1000~2000 主頁的文章==========

# %%
#20161130

# %%
j
# Out:
# 5958

# %%
parserSubmit=ParserSubmit()
count=21000
for j in range(5935,5959):
    if(count<0):
        break
    print "=========================nextpage===================="
    parserSubmit.connect()
    meauParser=MeauParser()
    parserObjects=[]
    
    urlist=meauParser.urlistUpdate('https://www.ptt.cc/bbs/Food/index'+str(j)+'.html')
    for i in urlist:
        try:
            parserObjects.append(FoodArticleParser(i))
        except:
            pass
    for i in parserObjects:
        parserSubmit.submit(i)
        count=count-1
        if(count<0):
            break
    parserSubmit.close()
    
print j
# Out:
# =========================nextpage====================
# 台南市中西區西門路一段658號B2
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區四維路14巷8號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 408台中市南屯區大英街414號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區松江街118號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 香港灣仔寶靈頓道21號鵝頸街市1樓熟食中心5號舖
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 香港銅鑼灣耀華街11號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新竹縣關西鎮仁安里拱子溝60號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市文山區木新路三段165號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市三重區自強路一段200號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市平鎮區廣平街171號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市中壢區日新路74號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區民生東路三段27號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市小港區宏平路299號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都大田区羽田空港2-6-5 東京国際線旅客ターミナル内4階 江戸小路
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市文山區興隆路四段104號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市新興區中山二路478號2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台中市西區自立街21號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區汀州路三段259號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區中山北路一段132號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區新生南路三段86巷19號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都中央區銀座6-9-3 不二家銀座ビル3F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都中央區銀座8-7-9 1階・2階
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 臺北市信義區松山路11號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 南投縣南投市中興路663-8
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區松江路259巷8號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市中西區民族路二段240號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市北區梅川西路三段66號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區永吉路30巷98號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市新店區建國路200號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區南京東路五段123巷6弄2-6號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台中市南屯區公益路二段830號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區安和路二段100號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市清水區鰲峰路16號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市八德區金和路85號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市新興區七賢一路7號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區市民大道四段219號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市北區長榮路四段58巷15號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都杉並区西荻南3-12-1 日伸西荻プラザ1F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市東區林森路一段276號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區光武街2巷10號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市中和區景安路136號2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區八德路三段12巷52弄18號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 花蓮市富吉路54號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市永和區永和路1段46號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大同區安西街106號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# :高雄市鳳山區五權路82號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西區公益路163號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 茨城県水戸市住吉町6-5
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都台東區淺草 1-13-4
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區忠孝東路四段216巷11弄4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市永康區中華路537號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 沖縄県中頭郡読谷村字座喜味367
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 花蓮縣花蓮市民國路38號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市瑞芳區金瓜石祈堂路7號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區民生東路二段60號(捷運行天宮站一號出口)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新竹市復興路75號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市小港區山明路273號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市中西區西門路一段658號6樓B區
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區林森北路247號5樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市士林區大北路7號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市中正區林森南路61巷3號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 彰化縣員林鎮中正路61號1-2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市新莊區中平路49號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區縣民大道三段270巷1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市內湖區康寧路三段54-9號B1
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西區華美街408號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市三重區長壽街132號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市至善路3段342號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 京都市東山區清水3-338-39
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新竹市東區勝利路32號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大同區承德路二段53巷16號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市東區東寧路335號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新竹市東大路四段67號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市士林區中山北路六段77號7樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 110台北市信義區松壽路12號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區雙十路二段209號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區大安路一段 19 巷 33 號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市深坑區深坑街162-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西屯區大恩街8號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# SchlegelstraBe 26C, 10115 Berlin Germany
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市鼓山區鼓波街19-2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區光復北路7號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市 西區華美街498巷9號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市新興區復興二路300-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市 信義區基隆路二段131-5號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 806高雄市前鎮區一心二路96號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西區五權一街116號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區汀州路三段104巷6號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市市府路13號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 捷運新埔站4號出口
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 臺北市中山區南京東路一段13巷6弄1號 (近捷運中山站)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市苓雅區興中一路10號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市北區林森路三段138號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 屏東縣東港鎮光復路一段409號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市中壢區實踐路88號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區泰順街33之5號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區中山北路二段20巷1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市苓雅區青年一路1-10號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 83065高雄市鳳山區大東一路90號之2
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市八德路二段206號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 香港銅鑼灣軒尼詩道500號希慎廣場12F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市安平區府前四街94號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區忠孝東路四段155號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市小港區飛機路542號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市北區育德路363號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 東京都豊島区東池袋3-1-1
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 大安區基隆路二段277號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 沖繩那霸市金城5-4-6
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區忠孝東路三段251巷13弄2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 80744高雄市三民區喜峰街100號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 文山區木新路三段67號1F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區南陽街17巷２號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市前鎮區中山二路244號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區漢口街一段15號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 基隆暖暖區過港路114號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市苓雅區苓雅一路240號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市旗津區廟前路56號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區基隆路一段333號33樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市大安區新生南路一段165巷20號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市鳳山區南榮路246號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區八德路三段12巷52弄2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都中央區月島 1-22-9
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市北屯區北屯路222-6號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市永和區民生路67巷20號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 花蓮縣光復鄉大全街62巷16號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區忠孝東路四段553巷26號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市中西區南寧街90號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市鳳山區五甲二路468號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 81359高雄市左營區辛亥路115號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市旗津區廟前路35號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區光復南路290巷53號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :屏東市忠孝路84-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市和平區達觀里6鄰東崎路一段天嶺巷1之4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 192-42 Donggyo-dong, Mapo-gu, Seoul, 韓國
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市萬華區貴陽街二段116號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 南投縣埔里鎮中山路三段215號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區復興北路81巷12號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 南投縣埔里鎮仁愛路319號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 店家:嘉義縣番路鄉下坑村菜公店1-3，4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市中和區自立路2巷7號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 4 Chome-10-30 Takanawa, 港区 Tokyo 108-8611日本
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 基隆市暖暖區源遠路278-7號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 香港中環伊利近街2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市新興區民生一路54號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市平鎮區復旦路二段271-2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 花蓮市新興路22號 (米老鼠旁)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區南陽街4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 923屏東縣萬巒鄉永康路134之1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新竹縣竹東鎮中豐路三段557號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 300新竹市東區金城二路38號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 104台北市中山區中山北路二段41號2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市永和區福和路288號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市文山區興隆路三段112巷2弄13號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 香港油麻寧波街23號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大同區寧夏路30-4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市文山區木新路二段61號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市臺灣大道二段405號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區敦化南路一段160巷24號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市左營區華夏路590號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市中興四巷4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市新興區達仁街88號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台南市北區旭日街103號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :屏東市中山路70-8號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區延吉街160巷9號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區仁愛路四段122巷48號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市新莊市中港路378號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 京都府京都市東山区本瓦町665
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市忠孝東路4段170巷17弄7號1F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區杭州南路一段63-4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市新莊區中平路184巷10弄2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市新市區中正路251號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區新東街26巷1-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大同區保安街49巷17號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區建國北路二段119號(行天宮站3號出口)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 新北市新店區民權路103號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山北路二段16巷22號(捷運中山站)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區忠孝東路四段181巷35弄21號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市健行路1005號(科博館與金典酒店附近)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市北投區承德路七段100號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市羅斯福路4段136巷10號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西區五權西二街34號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市前鎮區中華五路789號七樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市左營區南屏路297號2F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 花蓮市進豐街77號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市北屯區崇德路三段197號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市前金區六合二路137號前
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市大安區延吉街261號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市文山區景文街51號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市東區崇德路686號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 彰化縣埔心鄉員鹿路二段183號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市中壢區慈惠一街119號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市貢寮區仁和路51號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 南投縣國姓鄉北原路36-2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# Corner of 6th Ave & 42nd Street NYC
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西區中興街225號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市東區府連東路22巷1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 嘉義市西區民生北路179號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市三民區金鼎路&鼎力路口
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市新店區大豐路52號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市中山區市民大道三段29號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 宜蘭縣宜蘭市文昌路42號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市前鎮區中華五路789號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都 台東區 上野 6-2-6
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區仁化街64巷3號(近江子翠捷運站5號出口)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區仁愛路四段151巷35號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區復興北路81巷12號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市長安西路19巷2弄35-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區南京東路三段305-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西區向上路一段457號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 臺北市信義區松高路16號下2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市鼓山區文信路223號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都中央区銀座5-4-6
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新竹市東區西大路28號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 香港佐敦寧波街29號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市中正區金門街7號之1
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市前金區新田路268號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市中西區民生路二段188號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :台北市信義區忠孝東路五段31巷18弄5號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 臺北市大安區大安路一段51巷3號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 泰國 北碧府
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區莒光路165巷8號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市苓雅區和平一路101號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市鹽埕區七賢三路55號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區永康街48號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區仁愛路四段345巷4弄21號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都板橋区大谷口北町12-7 セブンマンション １Ｆ
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區松勤街54號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市中正區北平西路3號（台北火車站二樓）
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市安平區安平路590號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市永康區正強街201號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區莊敬路340號2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區南京東路五段21號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市文山區羅斯福路五段192巷8號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區光復南路202號2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市小港區漢民路691-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市台灣大道三段301號B2
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :台中市西區華美街408號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區縣民大道二段7號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市鳳山區光復路一段160號(青年路口)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區松壽路12號四樓(ATT4FUN四樓)
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區貴興路101號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市大安區信義路四段400巷6弄2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市平鎮區延平路一段207號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市北屯區北平路四段33號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市三民區十全二路39號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區濟南路2段6號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 京都府京都市下京区東塩小路町736
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市光復南路1段107巷5弄6號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區敦化南路一段236巷12號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區青島東路6-2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# : 新北市新莊區中和街155巷24弄18號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市士林區至誠路一段2之4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區健康路9號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# :高雄市三民區三鳳中街80-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市北區西屯路一段386號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區四維路170巷13號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# : 台北市忠孝東路五段805號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 信義新生路口
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區泰順街28號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 220新北市板橋區中山路一段152號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市左營區安吉街437號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區松江街74號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區建國北路一段92巷8號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都新宿区高田馬場2-2-1
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區光復南路280巷31號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區松高路11號B2
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 南投縣南投市鳳山里八卦路1100巷2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市板橋區新站路28號9樓（板橋大遠百）
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 桃園市中壢區中央東路58號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市前金區五福三路25號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市鼓山區濱海一路40號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市小港區山明路279號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區復興南路一段107巷5弄9號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 京都府京都市下京区橋本町103-2
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區南京東路二段178號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區南京東路二段178號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市左營區安吉街56號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市仁武區鳳仁路95-21號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區復興南路一段107巷5弄9號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市內湖區內湖路一段210號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區雙城街10巷25-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市信義區松壽路12號5F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區林森南路49號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區敦化北路155巷12號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市大同路60-1號2樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山路538之2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市洲子街61號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市新店區北新路二段97巷3號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區通化街19巷6弄2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市前鎮區中山二路260號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 嘉義市東區民族路420號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區敦化北路244巷51號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 高雄市左營區高鐵路123號10F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市士林區福國路52號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中正區懷寧街17號之3
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園蘆竹區光明路二段118號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 宜蘭縣員山鄉枕山一村19號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 大安區忠孝東路四段98號10樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 花蓮縣吉安鄉中正路一段156號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 10352台北市大同區建泰里南京西路18巷6弄6號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 嘉義市民雄鄉和平路43-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 埼玉県秩父市野坂町1-544-1
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市新興區復興二路223號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 台北市中山區民生東路二段115巷25弄2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市南港區南港路一段201號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新北市新店區大豐路27號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市苓雅區永康街71號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台南市中西區西門路一段706號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區松壽路2號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# :高雄市左營區軍校路190號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 小港區漢民路723號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市前金區自強一路148號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大安區安和路一段109巷4號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市大同區赤峰街53巷2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 新竹市北區興南街31號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 桃園市中壢區中平路163號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 高雄市新興區民生二路40號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區南京東路四段133巷4弄16號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 東京都豊島区東池袋1-12-15 近代グループ第二ビル 1F
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# =========================nextpage====================
# 桃園市中壢區龍東路532號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市松山區八德路二段447-1號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市華陰街33號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市士林區天母東路50巷22-9號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 日本〒103-0022 Tokyo, 中央区Nihonbashimuromachi, 1-11-15
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市信義區基隆路一段188-2號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台中市西屯區福林路78號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市中山區合江街180巷7號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 台北市士林區通河東街一段15號1樓
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 南投縣埔里鎮忠孝路245號
# sent to StoreTable
# sent to ArticleTable
# sent to Pushtable
# 5958

# %%
j
# Out:
# 5755

# %% [markdown]
# # 建立list parser

# %%
meauParser=MeauParser()
urlist=meauParser.urlistUpdate('https://www.ptt.cc/bbs/Food/index5661.html')
parserObjects=[]
for i in urlist:
    try:
        parserObjects.append(FoodArticleParser(i))
    except:
        pass

# %% [markdown]
# # 準備將資料存入DB

# %%
parserSubmit=ParserSubmit()

# %%
parserSubmit.connect()
for i in parserObjects:
    parserSubmit.submit(i)

# %%
parserSubmit.close()

# %% [markdown]
# # ================== 以下為 code 實驗區 ==================

# %%
#create a parser
c=FoodArticleParser('https://www.ptt.cc/bbs/Food/M.1470845681.A.06C.html')
c.get_push_tuple()

# %%
conn = psycopg2.connect("dbname='foodmining' user='penolove' host='localhost' password='password'")
cur = conn.cursor()

# %%
print c.get_store_tuple()[0]
print c.get_store_tuple()[1]
print c.get_store_tuple()[2]
print c.get_store_tuple()[3]

# %%
#insert to store table
if(c.name==""):
    cur.executemany("""INSERT INTO StoreTable(address,latlon,count) VALUES (%s,%s,%s) \
    ON CONFLICT (latlon) DO UPDATE SET count=StoreTable.count+1""", [c.get_store_tuple()])
else:
    cur.executemany("INSERT INTO StoreTable(address,storeName,latlon,count) VALUES (%s,%s,%s,%s) \
    ON CONFLICT (latlon) DO UPDATE SET count=StoreTable.count+1 , storeName='"+c.name+"'", [c.get_store_tuple()])

# %%
#insert to article table
cur.executemany("""INSERT INTO ArticleTable(latlon,title,Date,Author,Context,url) VALUES (%s,%s,%s,%s,%s,%s) """, [c.get_article_tuple()])

# %%
cur.executemany("""INSERT INTO PushTable(url,userid,pushtag,pushcontext) VALUES (%s,%s,%s,%s) """, c.get_push_tuple())

# %%
conn.commit()

# %%
conn.close()

# %%
##extract author,title,date
count=0
a=[];
for i in soup.select('.article-metaline'):
    count=0
    if(count==0):
        a.append(i.select('.article-meta-value')[0].text.split('(')[0].strip())
    else:
        a.append(i.select('.article-meta-value')[0].text.strip())
    count=count+1

# %%
res=requests.get('https://www.ptt.cc/bbs/Food/M.1470697166.A.FA5.html')
soup=BeautifulSoup(res.text)
main_context=soup.select('#main-content')[0].text

# %%
main_context=soup.select('.push')

# %%
#push-tag
main_context[0].select('.push-tag')[0].text
#ID
main_context[0].select('.push-userid')[0].text
#context
main_context[0].select('.push-content')[0].text[2:]

# %%
pushs=soup.select('.push')
[(i.select('.push-tag')[0].text,i.select('.push-userid')[0].text,i.select('.push-content')[0].text[2:]) for i in pushs ]

# %% [markdown]
# # parse meau

# %%
class meauparser():
    urlist=[]
    def urlistUpdate(self,url):
        res=requests.get(url)
        soup=BeautifulSoup(res.text)
        self.urlist=['https://www.ptt.cc'+i.select('a')[0]['href'] for i in soup.select('.r-ent')]
        return self.urlist

# %%
res=requests.get('https://www.ptt.cc/bbs/Food/index5661.html')
soup=BeautifulSoup(res.text)

# %%
soup.select('.r-ent')[0].select('a')[0]['href']

# %%
d=meauparser()

# %%
d.urlistUpdate('https://www.ptt.cc/bbs/Food/index5661.html')
